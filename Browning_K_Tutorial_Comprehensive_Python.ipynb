# %% [markdown]
# ## Kelly Browning - On my honor, as a student, I have neither given nor received unauthorized aid on this academic work. The assignment I am submitting is my own containing my own codes and words.

# %% [markdown]
# What is Python?  According to quora.com, for aspiring Data Scientists, Python is probably the most important language to learn because of its rich ecosystem. Python's major advantage is its breadth. For example, R can run Machine Learning algorithms on a preprocessed dataset, but Python is much better at processing the data. (quora.com)
#
# I have found that even a person that has little to no coding experience can pick up the basics of Python rather quickly.  Python also has hundreds of libraries that you can utilize in place of writing code that will do the same thing.  These libraries can be found at https://pypi.python.org/

# %% [markdown]
# ## Hello world
# Many programming language tutorials will start the learner out by having them create code that returns Hwllo world.  Just to show how much simpler it is in Python compared to other languages the example of Hello world is below

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ## Indenting is important!
#
# Most programming languages like C, C++, Java use braces { } to define a block of code. Python uses indentation.
#
# A block of code starts with indentation and ends with the first unindented line. Python will present you with an error if it is expectng an indentation and doesn't find it.
# Here is an example:

# %%
a = "you are beautiful"
b = "you are awesome"
 
if a == b:
    print 'equal' #this is part of the if statement block of code     
else:
    print 'not equal' #this is part of the else statement block of code
# Out:
# not equal

# %% [markdown]
# ## Comments

# %% [markdown]
# When writing code in any language comments are helpful for others to know what the code is intended to do.
# Comments in Python are denoted with the hash character, #.  A comment can begin .t the start of a line or following whitespace or code.Hashtags that are found within a string are not commentsbut actually consdered part of the string. Since comments are to clarify code, they are not interpreted by Python.

# %%
# this is a full line comment
var = 22  # This is an incode comment
          # this is a whitespace comment

text = "# This is not a comment because it's inside a text string."
text
# Out:
# "# This is not a comment because it's inside a text string."

# %% [markdown]
# ## Variables
#
# Variables are named locations which are used to store references to the object stored in memory. In python variables must follow these guidelines:
# All variables must start with letter or underscore ( _ ) , you can’t use numbers. For example myvar is valid variable while 1digit is not. Variables can contain letters, digits and underscores ( ). They can be of any length.

# %% [markdown]
# ## Python Data Types
#
# Python has 6 standard data types:
#
# a) Numbers
# b) String
# c) List
# d) Tuple
# e) Dictionary
# f) Boolean

# %% [markdown]
# ## Numbers
# Numbers in Python include integers, floating point numbers and complex numbers. They are defined as int, float and complex class.

# %%
a = 25              # an integer....a whole number
b = 3.5976      # a float...this means decimal points
print a
print b
# Out:
# 25
# 3.5976

# %%
#printing the result of an operation with a specified number of decimal places

x = 3.642985
y = 42.65
z = 84.3
total = x + y + z
print total #prints the entire total of the addition problem
print "%.2f"  % total #prints the total with two decimal places
print "%.5f"  % total #prints the total with five decimal places
print "%.3f"  % total #prints the total with three decimal places
# Out:
# 130.592985
# 130.59
# 130.59298
# 130.593

# %% [markdown]
# ## Strings
#
# A string is a sequence of characters. A character can be a letter, number, or special character.

# %%
name = "Kelly"    # a string

print name       # prints whole string
print name[0]    # prints the first position of the string or K
print name[0:2]  # prints the first and second positions of the string or Ke
# Out:
# Kelly
# K
# Ke

# %%
his_name = "Kevin"
his_age = 20

print "%s is %s years old" % (his_name, his_age)
# Out:
# Kevin is 20 years old

# %%
# create two string variables and one number variable
# concantenate all three values in a single line

month = "August"
day = 23
today_is = "Today is"

print "%s %s %s" % (today_is, month, day)
# Out:
# Today is August 23

# %% [markdown]
# ## Lists
# A list is also known as an array.  Each value is assigned an index or a position to enable location of the data.  In a list the first position or index is zero, the second is one and so one.

# %%
list = [1,2,3,4,5]  #contents of the list
for i in list: #i is the index or marker for each position in the list
 print i
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
len(list) #prints the length or size of the list
# Out:
# 5

# %%
print list     # prints all values of list
print list[0]  # print first value of list index is zero
print list[1]  # prints second value of list
print list[0:2] # print the first two items in list
print list[-1]  # print the last item in list
# Out:
# [1, 2, 3, 4, 5]
# 1
# 2
# [1, 2]
# 5

# %% [markdown]
# ## Tuple
#
# In Python Tuples are very similar to list but once a tuple is created, you cannot add, delete, replace, reorder elements.

# %%
#Functions like max , min , len , sum  can also be used with tuples.


t1 = (1, 12, 55, 12, 81) #create the tuple
print(t1)
# Out:
# (1, 12, 55, 12, 81)

# %%
min(t1) #minimum of the tuple
# Out:
# 1

# %%
max(t1) #maximum of the tuple
# Out:
# 81

# %%
sum(t1) #total of the tuple
# Out:
# 161

# %%
len(t1) #length of the tuple
# Out:
# 5

# %% [markdown]
# ## Dictionary
# Dictionary is a python data type that is used to store key value pairs. It enables you to quickly retrieve, add, remove, modify, values using key. Dictionary is very similar to what we call associative array or hash on other languages.

# %%
#create a dictionary
phonebook = {
'thelma' : '123-456-789',
'louise' : '987-654-321'
}

# %%
#retrieve information from dictionary


phonebook['thelma'] #retrieval using the key
# Out:
# '123-456-789'

# %%
#add items to dictionary
phonebook['popeye'] = '456-321-789'
phonebook
# Out:
# {'louise': '987-654-321', 'popeye': '456-321-789', 'thelma': '123-456-789'}

# %%
#delete item from dictionary
del phonebook['popeye']
phonebook
# Out:
# {'louise': '987-654-321', 'thelma': '123-456-789'}

# %%
#looping through items in dictionary
for key in phonebook:
 print(key, ":", phonebook[key])
# Out:
# ('louise', ':', '987-654-321')
# ('thelma', ':', '123-456-789')

# %% [markdown]
# ## Boolean
#  In Python True and False  are boolean literals

# %% [markdown]
# ## Keywords in Python

# %% [markdown]
# Keywords are reserved words and cannot be used for variable names, function names or any other type of identifier.  The following are considered to be keywords in Python:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Basic programming logic in Python

# %% [markdown]
# ## IF-statements
# The if statement in coding utilizes a condition that when it is satisfied activates a piece of code

# %%
a = "you are beautiful"
b = "you are awesome"
 
if a == b:
    print 'equal'      
else:
    print 'not equal'
# Out:
# not equal

# %%
a = 100
b = 10
if a < b:
   print 'a smaller than 10'
else:
   print 'a is bigger than 10 or equal'
# Out:
# a is bigger than 10 or equal

# %%
# create an if statement comparing two string values and print the result
a = "Friday"
b = "Monday"

if a == b:
        print 'TGIF!'
else:
        print 'Oh no, it is Monday!'
# Out:
# Oh no, it is Monday!

# %% [markdown]
# ## Loops
#
# A loop is a sequence of instructions that is repeated until a condition is reached.

# %%
# below is a list of data
items = [ "Abby","Brenda","Cindy","Diddy", 100 ]
 
for i in items:
    print i
# Out:
# Abby
# Brenda
# Cindy
# Diddy
# 100

# %%
items = [ "Abby","Brenda","Cindy","Diddy" ]
 
for i in items:
    print i + " is wonderful!"
# Out:
# Abby is wonderful!
# Brenda is wonderful!
# Cindy is wonderful!
# Diddy is wonderful!

# %%
# below is a list of data
items = [ "Abby","Brenda","Cindy","Diddy", 100 ]

for i in items:
    print i
    
print "There are %s items in the list" %len(items)
# Out:
# Abby
# Brenda
# Cindy
# Diddy
# 100
# There are 5 items in the list

# %%
# write a looping statement processing a list of strings and numbers


# show how many values in the list
group = ["dogs", "cats", "hamsters", "rabbits", 42, 50]

for i in group:
    print i
print "There are %s members in the group" %len(group)
# Out:
# dogs
# cats
# hamsters
# rabbits
# 42
# 50
# There are 6 members in the group

# %% [markdown]
# ## Including images or videos from the web in Python

# %%
# include an image from the web 

from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://s-media-cache-ak0.pinimg.com/736x/bc/f1/1e/bcf11ef78b531f812f2466ef2be94665--kansas-state-university-mission-statements.jpg")
# Out:
# <img src="https://s-media-cache-ak0.pinimg.com/736x/bc/f1/1e/bcf11ef78b531f812f2466ef2be94665--kansas-state-university-mission-statements.jpg"/>

# %%
# include a Youtube video about data analytics, big data, ...

from IPython.display import YouTubeVideo
YouTubeVideo('9hDnO_ykC7Y')

# %% [markdown]
# ## Reading and writing data files

# %%
# Read Excel file
import pandas as pd

data = pd.read_excel('data/SuperstoreSales.xlsx')
data
# Out:
#       Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0            3 2010-08-26            Low               6    261.5400
# 1            6 2012-01-03  Not Specified               2      6.9300
# 2           32 2011-05-28           High              15    140.5600
# 3           32 2011-05-28           High              24   1761.4000
# 4           32 2011-05-28           High              23    160.2335
# 5           32 2011-05-28           High              26   2808.0800
# 6           35 2011-09-04  Not Specified              30    288.5600
# 7           35 2011-09-04  Not Specified              14   1892.8480
# 8           36 2011-09-15       Critical              46   2484.7455
# 9           65 2011-01-28       Critical              32   3812.7300
# 10          66 2008-12-02            Low              41    108.1500
# 11          69 2009-04-16  Not Specified              42   1186.0600
# 12          69 2009-04-16  Not Specified              28     51.5300
# ...

# %%
# view first 5 rows
data.head()
# Out:
#    Order ID Order Date Order Priority  Order Quantity      Sales  Discount  \
# 0         3 2010-08-26            Low               6   261.5400      0.04
# 1         6 2012-01-03  Not Specified               2     6.9300      0.01
# 2        32 2011-05-28           High              15   140.5600      0.04
# 3        32 2011-05-28           High              24  1761.4000      0.09
# 4        32 2011-05-28           High              23   160.2335      0.04
#
#         Ship Mode    Profit  Unit Price  Shipping Cost    ...      \
# 0     Regular Air  -213.250       38.94          35.00    ...
# 1     Regular Air    -4.640        2.08           2.56    ...
# 2     Regular Air  -128.380        8.46           8.99    ...
# 3  Delivery Truck -1748.560       70.89          89.30    ...
# 4     Regular Air   -85.129        7.99           5.03    ...
#
#   Customer State Zip Code   Region Customer Segment Product Category  \
# ...

# %%
#find out basic statistics
data.describe()
# Out:
#            Order ID  Order Quantity         Sales     Discount        Profit  \
# count   8399.000000     8399.000000   8399.000000  8399.000000   8399.000000
# mean   29965.179783       25.575426   1774.860490     0.049664    181.401194
# std    17260.883447       14.482837   3585.107345     0.031826   1224.670845
# min        3.000000        1.000000      2.240000     0.000000 -16253.680000
# 25%    15011.500000       13.000000    143.035000     0.020000    -82.764250
# 50%    29857.000000       26.000000    449.420000     0.050000     -1.490000
# 75%    44596.000000       38.000000   1706.285000     0.080000    166.712250
# max    59973.000000       50.000000  89061.050000     0.250000  27220.690000
#
#         Unit Price  Shipping Cost      Zip Code  Product Base Margin
# count  8399.000000    8399.000000   8399.000000          8399.000000
# mean     89.310426      12.856427  48256.097631             0.512886
# std     290.361311      17.318257  30689.098271             0.135991
# ...

# %%
# select only two columns
order_info = data[['Order ID','Order Quantity']]
order_info.head()
# Out:
#    Order ID  Order Quantity
# 0         3               6
# 1         6               2
# 2        32              15
# 3        32              24
# 4        32              23

# %%
#To save order_info in a new excel file
order_info.to_excel("data/order_info.xlsx")

# to save in csv file 
# order_info.to_csv("data/order_info.csv")

# %% [markdown]
# ## Using python packages for data analysis
# Packages are namespaces which contain multiple packages and modules. They are directories.  There are many different packages in Python with equally as many different uses.

# %% [markdown]
# # Popular Python Packages for Data Analysis
#
# - Numpy and Scipy – fundamental scientific computing.
# - Pandas – data manipulation and analysis.
# - Matplotlib – plotting and visualization.
# - Seaborn - data visualization
# - Scikit-learn – machine learning and data mining.
# - StatsModels – statistical modeling, testing, and analysis.

# %%
#to install a python package you simply type pip install *package name in your c:// prompt window

# %% [markdown]
# ## Now we are going to transform the data file Superstores sales that we read in previously

# %% [markdown]
# ## Transforming data
# Transforming data is needed when you have missing or inaccurate values.  You can also transform data so that objects can be evaluated as numeric data types or that certain groups of data can be split out or binned in order to evaluate at a more granular level

# %% [markdown]
# ### Finding out data type & missing values

# %%
#data types & missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 21 columns):
# Order ID                8399 non-null int64
# Order Date              8399 non-null datetime64[ns]
# Order Priority          8399 non-null object
# Order Quantity          8399 non-null int64
# Sales                   8399 non-null float64
# Discount                8399 non-null float64
# Ship Mode               8399 non-null object
# Profit                  8399 non-null float64
# Unit Price              8399 non-null float64
# Shipping Cost           8399 non-null float64
# Customer Name           8399 non-null object
# Customer State          8399 non-null object
# Zip Code                8399 non-null int64
# Region                  8399 non-null object
# Customer Segment        8399 non-null object
# Product Category        8399 non-null object
# Product Sub-Category    8399 non-null object
# Product Name            8399 non-null object
# ...

# %% [markdown]
# ### This data doesn't have any missing values

# %% [markdown]
# ### Basic statistics

# %%
#Describe shows a quick statistic summary of your data
#this is a good way to examine the numerical columns
data.describe()
# Out:
#            Order ID  Order Quantity         Sales     Discount        Profit  \
# count   8399.000000     8399.000000   8399.000000  8399.000000   8399.000000
# mean   29965.179783       25.575426   1774.860490     0.049664    181.401194
# std    17260.883447       14.482837   3585.107345     0.031826   1224.670845
# min        3.000000        1.000000      2.240000     0.000000 -16253.680000
# 25%    15011.500000       13.000000    143.035000     0.020000    -82.764250
# 50%    29857.000000       26.000000    449.420000     0.050000     -1.490000
# 75%    44596.000000       38.000000   1706.285000     0.080000    166.712250
# max    59973.000000       50.000000  89061.050000     0.250000  27220.690000
#
#         Unit Price  Shipping Cost      Zip Code  Product Base Margin
# count  8399.000000    8399.000000   8399.000000          8399.000000
# mean     89.310426      12.856427  48256.097631             0.512886
# std     290.361311      17.318257  30689.098271             0.135991
# ...

# %%
data.hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000AF612B0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B2D4240>]], dtype=object)

# %%
# describe (statistics for a single column)
data['Sales'].describe()
# Out:
# count     8399.000000
# mean      1774.860490
# std       3585.107345
# min          2.240000
# 25%        143.035000
# 50%        449.420000
# 75%       1706.285000
# max      89061.050000
# Name: Sales, dtype: float64

# %%
# how many unique values in the Product Container column
data.groupby('Product Container').size()
# Out:
# Product Container
# Jumbo Box      526
# Jumbo Drum     620
# Large Box      402
# Medium Box     363
# Small Box     4360
# Small Pack     955
# Wrap Bag      1173
# dtype: int64

# %% [markdown]
# In your analysis you may find columns that are not needed for further analysis.  We will remove them

# %% [markdown]
# ### Remove (unnecessary) columns

# %%
# remove an unnecessary column (Order Priority)

data = data.drop('Order Priority', axis=1)
data.head()
# Out:
#    Order ID Order Date  Order Quantity      Sales  Discount       Ship Mode  \
# 0         3 2010-08-26               6   261.5400      0.04     Regular Air
# 1         6 2012-01-03               2     6.9300      0.01     Regular Air
# 2        32 2011-05-28              15   140.5600      0.04     Regular Air
# 3        32 2011-05-28              24  1761.4000      0.09  Delivery Truck
# 4        32 2011-05-28              23   160.2335      0.04     Regular Air
#
#      Profit  Unit Price  Shipping Cost       Customer Name Customer State  \
# 0  -213.250       38.94          35.00  Muhammed MacIntyre     New Jersey
# 1    -4.640        2.08           2.56         Ruben Dartt       New York
# 2  -128.380        8.46           8.99       Liz Pelletier           Ohio
# 3 -1748.560       70.89          89.30       Liz Pelletier           Ohio
# 4   -85.129        7.99           5.03       Liz Pelletier           Ohio
#
#    Zip Code   Region Customer Segment Product Category  \
# ...

# %%
# remove multiple columns (Zip Code, Customer Name, Customer State)
data = data.drop(['Zip Code', 'Customer Name','Customer State'], axis=1)
data.head()
# Out:
#    Order ID Order Date  Order Quantity      Sales  Discount       Ship Mode  \
# 0         3 2010-08-26               6   261.5400      0.04     Regular Air
# 1         6 2012-01-03               2     6.9300      0.01     Regular Air
# 2        32 2011-05-28              15   140.5600      0.04     Regular Air
# 3        32 2011-05-28              24  1761.4000      0.09  Delivery Truck
# 4        32 2011-05-28              23   160.2335      0.04     Regular Air
#
#      Profit  Unit Price  Shipping Cost   Region Customer Segment  \
# 0  -213.250       38.94          35.00     East   Small Business
# 1    -4.640        2.08           2.56     East        Corporate
# 2  -128.380        8.46           8.99  Central        Corporate
# 3 -1748.560       70.89          89.30  Central        Corporate
# 4   -85.129        7.99           5.03  Central        Corporate
#
#   Product Category           Product Sub-Category  \
# 0  Office Supplies         Storage & Organization
# ...

# %%
# how many missing values in each column or variable
data.isnull().sum()
# Out:
# Order ID                0
# Order Date              0
# Order Quantity          0
# Sales                   0
# Discount                0
# Ship Mode               0
# Profit                  0
# Unit Price              0
# Shipping Cost           0
# Region                  0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Name            0
# Product Container       0
# Product Base Margin     0
# Ship Date               0
# dtype: int64

# %% [markdown]
# ### Handling missing value
# there are different ways to handle missing values
# - drop them all
# - replace with certain values (e.g., mean, mode, median, specific valu

# %% [markdown]
# ## This dataset doesn't have any missing values but if there were this is the code you would use to drop them
# data_fix = data.dropna()
#
# data_fix.info()

# %% [markdown]
# ### Handling Inaccurate/Inconsistent Data
# - replace inaccurate values with null values and remove the row(s) with missing values
# - replace inaccurate values with different values

# %%
# create new columns
data['Total Cost'] = data['Sales'] + data['Shipping Cost']
data.head()
# Out:
#    Order ID Order Date  Order Quantity      Sales  Discount       Ship Mode  \
# 0         3 2010-08-26               6   261.5400      0.04     Regular Air
# 1         6 2012-01-03               2     6.9300      0.01     Regular Air
# 2        32 2011-05-28              15   140.5600      0.04     Regular Air
# 3        32 2011-05-28              24  1761.4000      0.09  Delivery Truck
# 4        32 2011-05-28              23   160.2335      0.04     Regular Air
#
#      Profit  Unit Price  Shipping Cost   Region Customer Segment  \
# 0  -213.250       38.94          35.00     East   Small Business
# 1    -4.640        2.08           2.56     East        Corporate
# 2  -128.380        8.46           8.99  Central        Corporate
# 3 -1748.560       70.89          89.30  Central        Corporate
# 4   -85.129        7.99           5.03  Central        Corporate
#
#   Product Category           Product Sub-Category  \
# 0  Office Supplies         Storage & Organization
# ...

# %%
# rename columns
data = data.rename(columns={'Shipping Cost': 'Shipping'})
data.head()
# Out:
#    Order ID Order Date  Order Quantity      Sales  Discount       Ship Mode  \
# 0         3 2010-08-26               6   261.5400      0.04     Regular Air
# 1         6 2012-01-03               2     6.9300      0.01     Regular Air
# 2        32 2011-05-28              15   140.5600      0.04     Regular Air
# 3        32 2011-05-28              24  1761.4000      0.09  Delivery Truck
# 4        32 2011-05-28              23   160.2335      0.04     Regular Air
#
#      Profit  Unit Price  Shipping   Region Customer Segment Product Category  \
# 0  -213.250       38.94     35.00     East   Small Business  Office Supplies
# 1    -4.640        2.08      2.56     East        Corporate  Office Supplies
# 2  -128.380        8.46      8.99  Central        Corporate       Technology
# 3 -1748.560       70.89     89.30  Central        Corporate        Furniture
# 4   -85.129        7.99      5.03  Central        Corporate       Technology
#
#             Product Sub-Category  \
# ...

# %%
# sampling data

#sampling 10 rows only
#data.index is the artifical number assigned to each row (e.g., 0,1,2,3,4,5) 
# ... for example, 1st row's index is 0, 2nd row's index is 1 ...
import random
#select 10 index numbers
rows = random.sample(data.index, 10)
#select 10 rows corresponding to those 10 index numbers
samp_10 = data.loc[rows]
samp_10
# Out:
#       Order ID Order Date  Order Quantity     Sales  Discount       Ship Mode  \
# 4015     28674 2011-06-28              26   161.960      0.00     Regular Air
# 5382     38274 2011-04-23               9  1225.370      0.08     Regular Air
# 2372     17187 2012-08-06               4  2951.970      0.09  Delivery Truck
# 2158     15491 2011-12-01               5   901.374      0.01     Regular Air
# 4984     35461 2009-04-14              11    48.750      0.08     Regular Air
# 7425     52930 2011-09-21              39   225.170      0.10     Regular Air
# 5402     38405 2010-05-28              29   208.040      0.10     Regular Air
# 5335     37920 2010-05-27              48   414.420      0.04     Regular Air
# 273       1891 2009-10-27               3   302.360      0.09     Regular Air
# 4986     35490 2010-10-20               7    44.640      0.03     Express Air
#
#         Profit  Unit Price  Shipping   Region Customer Segment  \
# ...

# %%
# sort data by column

#sorting: ascending=True is the default
samp_10.sort_values(by=['Profit'])
# Out:
#       Order ID Order Date  Order Quantity     Sales  Discount       Ship Mode  \
# 2372     17187 2012-08-06               4  2951.970      0.09  Delivery Truck
# 2158     15491 2011-12-01               5   901.374      0.01     Regular Air
# 5335     37920 2010-05-27              48   414.420      0.04     Regular Air
# 7425     52930 2011-09-21              39   225.170      0.10     Regular Air
# 4015     28674 2011-06-28              26   161.960      0.00     Regular Air
# 5382     38274 2011-04-23               9  1225.370      0.08     Regular Air
# 4986     35490 2010-10-20               7    44.640      0.03     Express Air
# 4984     35461 2009-04-14              11    48.750      0.08     Regular Air
# 5402     38405 2010-05-28              29   208.040      0.10     Regular Air
# 273       1891 2009-10-27               3   302.360      0.09     Regular Air
#
#         Profit  Unit Price  Shipping   Region Customer Segment  \
# ...

# %% [markdown]
# ## Creating charts in Python
# Charts in python allow you to visualize different aspects/relationships in your data

# %%
#import python packages (these are the most popular ones)
import matplotlib.pyplot as plt
# %matplotlib inline

# import some other packages
import numpy as np
import pandas as pd
import seaborn as sns  #package for statistical data visualization

# %% [markdown]
# ## Pivot table
# Pivot tables are useful for summarizing data. They can automatically sort, count, total, or average data stored in one table. Then, they can show the results of those actions in a new table of that summarized data

# %%
# pivot table for Region
data.groupby(['Region']).count()
# Out:
#          Order ID  Order Date  Order Quantity  Sales  Discount  Ship Mode  \
# Region
# Central      2088        2088            2088   2088      2088       2088
# East         1769        1769            1769   1769      1769       1769
# South        2282        2282            2282   2282      2282       2282
# West         2260        2260            2260   2260      2260       2260
#
#          Profit  Unit Price  Shipping  Customer Segment  Product Category  \
# Region
# Central    2088        2088      2088              2088              2088
# East       1769        1769      1769              1769              1769
# South      2282        2282      2282              2282              2282
# West       2260        2260      2260              2260              2260
#
#          Product Sub-Category  Product Name  Product Container  \
# Region
# Central                  2088          2088               2088
# East                     1769          1769               1769
# ...

# %%
# pivot table for Sales
data.groupby(['Sales']).count()
# Out:
#           Order ID  Order Date  Order Quantity  Discount  Ship Mode  Profit  \
# Sales
# 2.24             1           1               1         1          1       1
# 3.20             1           1               1         1          1       1
# 3.23             1           1               1         1          1       1
# 3.41             1           1               1         1          1       1
# 3.42             1           1               1         1          1       1
# 3.63             1           1               1         1          1       1
# 3.77             1           1               1         1          1       1
# 3.85             1           1               1         1          1       1
# 3.96             1           1               1         1          1       1
# 4.94             1           1               1         1          1       1
# 4.97             1           1               1         1          1       1
# ...

# %%
# pivot table for Profit
data.groupby(['Profit']).count()
# Out:
#              Order ID  Order Date  Order Quantity  Sales  Discount  Ship Mode  \
# Profit
# -16253.6800         1           1               1      1         1          1
# -14434.4800         1           1               1      1         1          1
# -13775.1700         1           1               1      1         1          1
# -11861.4600         1           1               1      1         1          1
# -11797.3100         1           1               1      1         1          1
# -11769.1700         1           1               1      1         1          1
# -11053.6000         1           1               1      1         1          1
# -9851.0900          1           1               1      1         1          1
# -9643.0700          1           1               1      1         1          1
# -9611.9100          1           1               1      1         1          1
# -9151.0700          1           1               1      1         1          1
# ...

# %% [markdown]
# ### Histogram
# A histogram is visualization of numeric columns in a dataset.  The set of charts below show all of the numeric columns in the Supersales dataset

# %%
# histogram for all numerical columns
#only numeric columns are displayed in histograms
data.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C910240>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EA8FC50>]], dtype=object)

# %%
#overlapping two graphs

data.groupby('Region').Sales.hist(alpha=0.9)
# Out:
# Region
# Central    Axes(0.125,0.125;0.775x0.755)
# East       Axes(0.125,0.125;0.775x0.755)
# South      Axes(0.125,0.125;0.775x0.755)
# West       Axes(0.125,0.125;0.775x0.755)
# Name: Sales, dtype: object

# %%
# linear regression & scatter chart for Profit and Sales
sns.lmplot("Profit", "Sales", data, x_jitter=.15)

# %%
# linear regression & scatter chart for Sales and Region
sns.lmplot("Sales", "Profit", data, hue="Region", x_jitter=.15, size=8)

# %%
# factorplot for Sales and Region
sns.factorplot("Sales", "Region", data=data)

# %%
# factorplot for Profit and Region
sns.factorplot("Profit", "Region", data=data)

# %% [markdown]
# ## Interactive charts

# %%
#heatmap in Bokeh allows you to click on the chart and drill down

from bokeh.charts import HeatMap, show, output_file

hm = HeatMap(data, x="Region", y="Profit", values='Sales', title='Sales by Region', stat=None)
show(hm)
# Out:
# C:\anaconda\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)
# No handlers could be found for logger "C:\anaconda\lib\site-packages\bokeh\core\validation\check.pyc"

# %% [markdown]
# ## Correlation analysis
# Correlation = What?
#
# Large sample sizes (big data)
#
# Hidden patterns and insights from data
#
# Industry & problem soving focus
#
# Correlations
# Correlation coefficients (r)
#
#           -1 <= r <= 1
# -1 highly negative
#
# +1 highly positive
#
# 0 no relationship
#
# +/- 0.3 considered meaningful

# %%
#transform Region from an object to an integer to be able to run correlation analysis on it
data['Region'] = data['Region'].map({'East': 1, 'West': 2, 'Central': 3, 'South': 4})
data.head()
# Out:
#    Order ID Order Date  Order Quantity      Sales  Discount       Ship Mode  \
# 0         3 2010-08-26               6   261.5400      0.04     Regular Air
# 1         6 2012-01-03               2     6.9300      0.01     Regular Air
# 2        32 2011-05-28              15   140.5600      0.04     Regular Air
# 3        32 2011-05-28              24  1761.4000      0.09  Delivery Truck
# 4        32 2011-05-28              23   160.2335      0.04     Regular Air
#
#      Profit  Unit Price  Shipping  Region Customer Segment Product Category  \
# 0  -213.250       38.94     35.00       1   Small Business  Office Supplies
# 1    -4.640        2.08      2.56       1        Corporate  Office Supplies
# 2  -128.380        8.46      8.99       3        Corporate       Technology
# 3 -1748.560       70.89     89.30       3        Corporate        Furniture
# 4   -85.129        7.99      5.03       3        Corporate       Technology
#
#             Product Sub-Category  \
# ...

# %% [markdown]
# ## Correlation of -+.30 is thought to be meaningful

# %%
data.corr()
# Out:
#                      Order ID  Order Quantity     Sales  Discount    Profit  \
# Order ID             1.000000        0.011461 -0.006822 -0.003568 -0.005849
# Order Quantity       0.011461        1.000000  0.220413 -0.010160  0.196062
# Sales               -0.006822        0.220413  1.000000 -0.018951  0.577657
# Discount            -0.003568       -0.010160 -0.018951  1.000000 -0.038563
# Profit              -0.005849        0.196062  0.577657 -0.038563  1.000000
# Unit Price          -0.003867       -0.104341  0.602518  0.001760 -0.035542
# Shipping            -0.003857       -0.012162  0.434261 -0.000269 -0.018124
# Region               0.015713       -0.009947  0.003252  0.007180  0.011058
# Product Base Margin -0.024529        0.006781  0.157456  0.005559 -0.106292
# Total Cost          -0.006826        0.219891  0.999991 -0.018913  0.576355
#
#                      Unit Price  Shipping    Region  Product Base Margin  \
# ...

# %%
 #find out correlation of two columns: Sales, Unit Price
data[['Sales','Unit Price']].corr()
# Out:
#                Sales  Unit Price
# Sales       1.000000    0.602518
# Unit Price  0.602518    1.000000

# %%
#What is the relationship of Order Quantity, Region, Unit Price  and Sales?

#sns.factorplot( "Profit", "Order Quantity", "Unit Price",  data = data, col="Region", aspect=.75)

# %%
#find out correlation of two columns: Region, Profit
data[['Region','Profit']].corr()
# Out:
#           Region    Profit
# Region  1.000000  0.011058
# Profit  0.011058  1.000000

# %%
#find out correlation of two columns: Sales, Unit Price
data[['Sales','Unit Price']].corr()
# Out:
#                Sales  Unit Price
# Sales       1.000000    0.602518
# Unit Price  0.602518    1.000000

# %% [markdown]
# ### A heatmap can show you visually where the stronger correlations are in your dataset.

# %%
from seaborn.linearmodels import corrplot,symmatplot
# correlation plot
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(), vmax=.8,
square=True, annot=True, fmt=".1f")

# %% [markdown]
# ### This is a seaborn chart that is a subplot grid for plotting pairwise relationships in a dataset.

# %%
g = sns.PairGrid(data)
g.map(plt.scatter)

# %%
# an illustration of normal distribution
from scipy import stats
h = sorted(data['Profit'])
fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting
plt.plot(h,fit,'-o')
plt.hist(h,normed=True)      #use this to draw histogram of your data
# Out:
# (array([  8.21599897e-08,   3.28639959e-07,   6.84666581e-07,
#           2.12301413e-04,   1.43779982e-05,   1.94445309e-06,
#           2.46479969e-07,   2.73866632e-08,   0.00000000e+00,
#           2.73866632e-08]),
#  array([-16253.68 , -11906.243,  -7558.806,  -3211.369,   1136.068,
#           5483.505,   9830.942,  14178.379,  18525.816,  22873.253,
#          27220.69 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## This has a nice bell curve indicating that this data is normally distributed

# %%
h = sorted(data['Region'])
fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting indeed
plt.plot(h,fit,'-o')
plt.hist(h,normed=True)      #use this to draw histogram of your data
# Out:
# (array([ 0.70206771,  0.        ,  0.        ,  0.89693217,  0.        ,
#          0.        ,  0.82867008,  0.        ,  0.        ,  0.90566337]),
#  array([ 1. ,  1.3,  1.6,  1.9,  2.2,  2.5,  2.8,  3.1,  3.4,  3.7,  4. ]),
#  <a list of 10 Patch objects>)

# %%
h = sorted(data['Sales'])
fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting indeed
plt.plot(h,fit,'-o')
plt.hist(h,normed=True)      #use this to draw histogram of your data
# Out:
# (array([  1.07579503e-04,   3.44917506e-06,   1.04277385e-06,
#           1.73795642e-07,   1.33688956e-08,   1.33688956e-08,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.33688956e-08]),
#  array([  2.24000000e+00,   8.90812100e+03,   1.78140020e+04,
#           2.67198830e+04,   3.56257640e+04,   4.45316450e+04,
#           5.34375260e+04,   6.23434070e+04,   7.12492880e+04,
#           8.01551690e+04,   8.90610500e+04]),
#  <a list of 10 Patch objects>)

# %%
# find out correlation of two columns: Profit, Region
data[['Profit','Sales']].corr()
# Out:
#           Profit     Sales
# Profit  1.000000  0.577657
# Sales   0.577657  1.000000

# %%
# test if the data is normally distributed

import scipy.stats as stats

print stats.normaltest(data['Region'])
print stats.normaltest(data['Sales'])
# Out:
# NormaltestResult(statistic=52218.68983938895, pvalue=0.0)
# NormaltestResult(statistic=9208.4431994473307, pvalue=0.0)

# %% [markdown]
# A statistically significant correlation is indicated by a probability value of less than 0.05.

# %%
 region = stats.normaltest(data['Region'])
sales = stats.normaltest(data['Sales'])
# this allows you to print just three decimal places %.3f
print "The chi-square statistic is %.3f and the p-value is %.3f." % region
print "The chi-square statistic is %.3f and the p-value is %.3f." % sales
# Out:
# The chi-square statistic is 52218.690 and the p-value is 0.000.
# The chi-square statistic is 9208.443 and the p-value is 0.000.

# %%
# jointplott for Sales and Unit Price
sns.jointplot("Sales", "Total Cost", data, kind="hex", color="#8855AA")

# %%
# find out variance
data.var()
# Out:
# Order ID               2.979381e+08
# Order Quantity         2.097526e+02
# Sales                  1.285299e+07
# Discount               1.012914e-03
# Profit                 1.499819e+06
# Unit Price             8.430969e+04
# Shipping               2.999220e+02
# Region                 1.208160e+00
# Product Base Margin    1.849357e-02
# Total Cost             1.290722e+07
# dtype: float64

# %%
# boxplot
data.boxplot()

# %%
data.boxplot('Order Quantity', by='Region', figsize=(8, 3))

# %%
data.boxplot('Total Cost', by='Region', figsize=(8, 3))

# %%
east = data[data['Region'] == 1 ]['Sales']
west = data[data['Region'] == 2]['Sales']
central = data[data['Region'] == 3]['Sales']
south = data[data['Region'] == 4]['Sales']

f_val, p_val = stats.f_oneway(east, west, central, south)  
  
print "One-way ANOVA P =", p_val
# Out:
# One-way ANOVA P = 0.861217734971

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

mod = ols('Region ~ Sales', data=data).fit()
                
aov_table = sm.stats.anova_lm(mod)
print aov_table
# Out:
# C:\anaconda\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#               df        sum_sq   mean_sq         F    PR(>F)
# Sales        1.0      0.107280  0.107280  0.088787  0.765732
# Residual  8397.0  10146.020354  1.208291       NaN       NaN
# C:\anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\anaconda\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

print pairwise_tukeyhsd(data['Sales'], data['Region'])
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff   lower    upper   reject
# ------------------------------------------------
#   1      2    -74.1817 -366.6612 218.2978 False
#   1      3    -30.5028 -328.2245 267.2189 False
#   1      4    11.3684  -280.4914 303.2282 False
#   2      3    43.6789  -235.9874 323.3452 False
#   2      4    85.5501  -187.8675 358.9677 False
#   3      4    41.8712   -237.147 320.8894 False
# ------------------------------------------------

# %% [markdown]
# ## Functions
# A function is a block of organized, reusable code that is used to perform a single, related action.
# Function blocks begin with the keyword def followed by the function name and parentheses ( ( ) ).
# Any input parameters or arguments should be placed within these parentheses. You can also define parameters inside these parentheses.
# The first statement of a function can be an optional statement - the documentation string of the function or docstring.
# The code block within every function starts with a colon (:) and is indented.
# The statement return [expression] exits a function, optionally passing back an expression to the caller. A return statement with no arguments is the same as return None. (tutorialspoint.com)

# %%
def printme( str ):
   "This prints a passed string into this function"
   print str
   return

# %%
# Function definition is here
def firstfunction( str ):
    print str
    return;

# Now you can call firstfunction
firstfunction("This is the first call")
firstfunction("This is the second call")
# Out:
# This is the first call
# This is the second call

# %% [markdown]
# Functions may also receive arguments (variables passed from the caller to the function). For example:

# %%
def secondfunction(name, wish):
 print("Hello, %s, I wish you %s"%(name, wish))
secondfunction("Student", "a great day!") # this supplies the arguments to the function
# Out:
# Hello, Student, I wish you a great day!

# %% [markdown]
# Functions are a way to break your code into blocks.  This allows you to order code making it easier to read and reuse. Functions enable programmers to share their code.

# %% [markdown]
# ## Classes
# A class can be thought of as a blueprint. It gives us instructions on how to create something. You can create lots of objects from that blueprint - known technically as instances.
#
# Classes start with keyword class:

# %%
class FirstClass:
	"This is an example of class"
	var1 = "class 1"
	def func(self):
		print('Hello')

# Output: class 1
print(FirstClass.var1)

# Output: 'This is an example class'
print(FirstClass.__doc__)
# Out:
# class 1
# This is an example of class

# %% [markdown]
# ## Another class with explanation

# %%
#An example of a class
class Box:

    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.description = "awaiting description of box"
        self.author = "awaiting author of box"

    def area(self):
        return self.x * self.y

    def perimeter(self):
        return 2 * self.x + 2 * self.y

    def describe(self, text):
        self.description = text

    def authorName(self, text):
        self.author = text

    def scaleSize(self, scale):
        self.x = self.x * scale
        self.y = self.y * scale

# %% [markdown]
# This class or blueprint gives us a  description of a box.This is not the actual box just the description of what a box is. The box has a width (x), a height (y), and an area and perimeter (area(self) and perimeter(self)). We are not running code, just defining the class and it's variables and functions
#
# A function called __init__ is designed to run at the creation of an instance of the box.
#
# self is how we refer to things in the class. self is the first parameter in any function defined inside a class. Any function or variable created on the first level of indentation (that is, lines of code that start one TAB to the right of where we put class Box) is automatically put into self.

# %% [markdown]
# To use a class you need to create an instance.  The code below defines the instance of Box and it's parameters.

# %%
rectangle = Box(120, 60)

# %% [markdown]
# Once this code is ran the __init__ function comes into play. It creates an instance of a class Box and uses the values in the brackets to satisfy the parameters of self.  This box is a rectangle
#
# The rectangle is an instance of class Box.

# %%
#find the area of rectangle:
print(rectangle.area())

#find the perimeter of rectangle:
print(rectangle.perimeter())

#describe the rectangle
rectangle.describe("This is a rectangle that is wider than it is tall")
# Out:
# 7200
# 360

# %% [markdown]
# This has been my tutorial of Python.  I hope you found it useful

# %% [markdown]
# ## References:
#
# https://www.quora.com/Is-Python-the-most-important-programming-language-to-learn-for-aspiring-data-scientists-and-data-miners
#
# https://docs.python.org/3/tutorial/introduction.html
#
# https://www.learnpython.org/en/Modules_and_Packages
#
#  http://stackoverflow.com/:
#
# http://en.wikibooks.org/wiki/Non-Programmer%27s_Tutorial_for_Python_2.6/Lists
#
# https://www.tutorialspoint.com/python/python_functions.htm
